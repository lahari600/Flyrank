# %% [markdown]
# <a href="https://colab.research.google.com/github/lahari600/Flyrank/blob/main/work/notebooks/w02_ml_task_framing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/lahari600/Flyrank/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %% [markdown]
# ## My Lane as an ML Task
#
# **Lane:** Content Refresh Prioritization
#
# **ML Task Type:** Classification
#
# The goal is to classify web pages into two groups: pages that should be refreshed and pages that do not need refreshing. The model will learn from historical content performance metrics to recommend which pages should be updated first.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %% [markdown]
# ## Target or Proxy
#
# The target is whether a web page should be refreshed.
#
# Since there is no direct label in the dataset, a proxy target can be created using the trend direction. Pages with a **down** trend will be treated as pages needing a refresh, while pages with stable or improving trends will be treated as not requiring immediate refresh.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %% [markdown]
# ## Success Metric
#
# The primary success metric is Precision because the content team wants the recommended pages to truly need refreshing.
#
# A high precision score means that most recommended pages are valuable refresh candidates, reducing wasted effort.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %% [markdown]
# ## Unit of Analysis
#
# Each row in the dataset represents one web page.
#
# Each page contains information such as search volume, impressions, CTR, average position, content age, word count, and trend direction.
#
# The model predicts whether that page should be refreshed.

# %%
import pandas as pd

df = pd.read_csv("Flyrank/data/raw/content_refresh_anonymized.csv")

print("Dataset Shape:", df.shape)

print("\nFirst Five Rows:")
display(df.head())

print("\nColumns:")
print(df.columns.tolist())
# Out:
# Dataset Shape: (30000, 44)
#
# First Five Rows:
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# 1  content_a1fb4e703a9e  client_4e07408562           90.0         0.01
# 2  content_9aa793d4d895  client_7f2253d7e2            0.0         0.00
# 3  content_331d6c4de07b  client_19581e27de           10.0         0.00
# 4  content_d99b7a2d90ca  client_3fdba35f04            0.0         0.00
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# 0              HIGH  2.05  keyword article  transactional      3221.0
# 1               LOW  0.05  keyword article  informational      2481.0
# 2               LOW  0.00  keyword article  informational      3515.0
# 3               LOW  0.00  keyword article     commercial         NaN
# 4               LOW  0.00  keyword article  informational      2803.0
#
# ...

# %%
# !git clone https://github.com/lahari600/Flyrank.git
# Out:
# fatal: destination path 'Flyrank' already exists and is not an empty directory.

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %% [markdown]
# ## Why ML Beats a Fixed Rule
#
# A fixed rule such as "refresh pages older than one year" ignores many important factors.
#
# Machine learning can analyze multiple features together, including CTR, impressions, search volume, average position, content age, and trend direction.
#
# By combining these signals, the model can recommend pages more accurately than a simple rule.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.

# %% [markdown]
# ## Self Check
#
#  Identified the ML task type.
#  Defined the target/proxy.
#  Selected a success metric.
#  Displayed the unit of analysis as a dataframe.
#  Explained why machine learning is better than a fixed rule.
